# %% [markdown]
# # Marvel Movies Dataset - Buget & Profits

# %% [markdown]
# ## Load required packages

# %%
# MARVEL MOVIES DATASET ANALYSIS
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
asia_pacific = pd.read_csv('asia_pacific_box_office.csv')
europe = pd.read_csv('europe_box_office.csv')
middle_east_and_africa = pd.read_csv('middle_east_and_africa_box_office.csv')
north_america = pd.read_csv('north_america_box_office.csv')
south_america = pd.read_csv('south_america_box_office.csv')
mcu_movie_info_df = pd.read_csv('movie_info.csv')

# %% [markdown]
# ## Data checks

# %% [markdown]
# #### How Many Rows and Columns does the data have?

# %%
asia_pacific.shape
# Out:
# (28, 17)

# %%
europe.shape
# Out:
# (27, 31)

# %%
middle_east_and_africa.shape
# Out:
# (27, 13)

# %%
north_america.shape
# Out:
# (27, 5)

# %%
south_america.shape
# Out:
# (27, 12)

# %% [markdown]
# #### What are the column names?

# %%
asia_pacific.columns
# Out:
# Index(['Movie Title', 'South Korea', 'Russia/CIS', 'Japan', 'Thailand',
#        'Indonesia', 'India', 'Taiwan', 'Philippines', 'Singapore', 'Vietnam',
#        'Malaysia', 'Hong Kong', 'New Zealand', 'Australia', 'China',
#        'Other_Asia_Pacific_Countries'],
#       dtype='object')

# %%
europe.columns
# Out:
# Index(['movie_title', 'United Kingdom', 'Spain', 'Italy', 'Germany', 'Denmark',
#        'Hungary', 'Finland', 'Netherlands', 'Iceland', 'Czech Republic',
#        'Switzerland', 'Slovakia', 'Ukraine', 'Portugal', 'Romania',
#        'Lithuania', 'Bulgaria', 'Latvia', 'Croatia', 'Austria', 'Poland',
#        'Serbia and Montenegro', 'Estonia', 'Slovenia', 'Sweden', 'Belgium',
#        'Norway', 'Greece', 'France', 'Other_European_Countries'],
#       dtype='object')

# %%
middle_east_and_africa.columns
# Out:
# Index(['movie_title', 'United Arab Emirates', 'Israel', 'South Africa',
#        'Nigeria', 'Ghana', 'Kenya', 'East Africa', 'Lebanon', 'Egypt',
#        'Kuwait', 'Turkey', 'Other_Middle_East_and_African_Countries'],
#       dtype='object')

# %%
north_america.columns
# Out:
# Index(['movie_title', 'USA_and_Canada', 'Mexico', 'Central America',
#        'Caribbean'],
#       dtype='object')

# %%
south_america.columns
# Out:
# Index(['movie_title', 'Venezuela', 'Colombia', 'Bolivia', 'Uruguay', 'Peru',
#        'Paraguay', 'Chile', 'Ecuador', 'Argentina', 'Brazil',
#        'Other_South_American_Countries'],
#       dtype='object')

# %% [markdown]
# #### Look at the first 5 rows

# %%
asia_pacific.head()
# Out:
#                           Movie Title South Korea Russia/CIS     Japan  \
# 0                            Iron Man     $25.17      $9.49     $8.66
# 1                 The Incredible Hulk      $6.38      $6.41     $1.69
# 2                          Iron Man 2     $27.10     $14.76    $12.83
# 3                                Thor     $14.79     $16.54     $5.74
# 4  Captain America: The First Avenger      $3.81      $8.64     $3.43
#
#   Thailand Indonesia    India   Taiwan Philippines Singapore  Vietnam  \
# 0   $2.45     $2.15    $1.99    $5.37       $3.99     $3.82       NaN
# 1   $1.18     $1.50    $3.14    $1.94       $2.07     $1.84    $0.16
# 2   $4.62     $4.49    $1.23    $4.04       $6.25     $4.19       NaN
# 3   $2.32     $0.27    $1.00    $5.83       $4.03     $4.25       NaN
# 4   $2.48     $2.05    $0.12    $6.32       $3.58     $3.56    $0.60
#
#   Malaysia Hong Kong New Zealand Australia     China  \
# 0   $3.47     $2.84       $2.73    $19.09    $15.27
# ...

# %%
asia_pacific.sort_values(by="South Korea", ascending=False).head(1)
# Out:
#                Movie Title South Korea Russia/CIS     Japan  Thailand  \
# 18  Avengers: Infinity War     $81.74     $34.60    $33.88    $17.94
#
#    Indonesia     India    Taiwan Philippines Singapore Vietnam  Malaysia  \
# 18   $25.29    $43.59    $21.59      $23.30    $12.20      NaN   $17.33
#
#    Hong Kong New Zealand Australia      China Other_Asia_Pacific_Countries
# 18   $20.59       $7.09    $46.83    $359.54                       $18.11

# %%
europe.head()
# Out:
#                           movie_title  United Kingdom  Spain  Italy  Germany  \
# 0                            Iron Man           34.28  12.03  10.81     8.56
# 1                 The Incredible Hulk           15.16   7.69   6.46     2.46
# 2                          Iron Man 2           30.46   7.60   9.98     9.25
# 3                                Thor           22.52  12.44  10.90    16.01
# 4  Captain America: The First Avenger           14.75   7.71   8.60     4.87
#
#    Denmark  Hungary  Finland  Netherlands  Iceland  ...  Poland  \
# 0     2.22     0.68     0.67         2.10     0.28  ...    1.00
# 1     1.10     0.31     0.22         1.34     0.15  ...    0.48
# 2     2.29     0.70     0.80         2.14     0.20  ...    1.14
# 3     1.53     0.74     0.42         1.95     0.26  ...    1.61
# 4     1.05     0.51     0.31         1.63     0.20  ...    0.45
#
#    Serbia and Montenegro  Estonia  Slovenia  Sweden  Belgium  Norway  Greece  \
# ...

# %%
middle_east_and_africa.head()
# Out:
#                           movie_title  United Arab Emirates  Israel  \
# 0                            Iron Man                  1.84    0.61
# 1                 The Incredible Hulk                  1.81    0.49
# 2                          Iron Man 2                  2.25    0.68
# 3                                Thor                  2.07    0.75
# 4  Captain America: The First Avenger                  1.33    0.72
#
#    South Africa  Nigeria  Ghana  Kenya  East Africa  Lebanon  Egypt  Kuwait  \
# 0          1.46     0.05    NaN    NaN         0.09     0.10   0.27    0.84
# 1          0.93     0.03    NaN    NaN         0.08     0.10   0.28    0.66
# 2          2.59     0.06   0.01    NaN         0.12     0.17   0.30     NaN
# 3          2.01     0.14   0.03    NaN         0.05     0.28   0.16     NaN
# 4          1.04     0.06   0.02    NaN         0.04     0.17   0.11     NaN
#
#    Turkey  Other_Middle_East_and_African_Countries
# ...

# %%
north_america.head()
# Out:
#                           movie_title  USA_and_Canada  Mexico  \
# 0                            Iron Man          319.03   15.95
# 1                 The Incredible Hulk          134.81   12.65
# 2                          Iron Man 2          312.43   18.40
# 3                                Thor          181.03   19.55
# 4  Captain America: The First Avenger          176.65   20.22
#
#    Central America  Caribbean
# 0             1.37       1.37
# 1             0.70       0.70
# 2             6.57       6.57
# 3             5.29       5.29
# 4             3.84       3.84

# %%
south_america.head()
# Out:
#                           movie_title  Venezuela  Colombia  Bolivia  Uruguay  \
# 0                            Iron Man       1.89      1.73     0.15     0.07
# 1                 The Incredible Hulk       1.31      0.75     0.07     0.02
# 2                          Iron Man 2       1.90      1.28     0.31     0.10
# 3                                Thor       2.65      2.47     0.37     0.08
# 4  Captain America: The First Avenger       1.08      2.78     0.37     0.09
#
#    Peru  Paraguay  Chile  Ecuador  Argentina  Brazil  \
# 0  1.52       NaN   1.38     0.93       1.61   13.50
# 1  1.19       NaN   0.34     0.38       0.94    4.89
# 2  1.86       NaN   1.45     1.24       2.57   15.84
# 3  1.97       NaN   1.25     1.28       2.40   12.09
# 4  2.39       NaN   1.62     1.49       3.54   20.68
#
#    Other_South_American_Countries
# 0                            1.37
# 1                            0.70
# 2                            6.57
# 3                            5.29
# ...

# %% [markdown]
# #### Describe the various values, what are the maximum and minimum values?

# %%
asia_pacific.describe()
# Out:
#        Movie Title South Korea Russia/CIS    Japan Thailand Indonesia  \
# count           27          27         27       27       27        20
# unique          27          27         27       27       27        20
# top       Iron Man     $25.17      $9.49    $8.66    $2.45     $2.15
# freq             1           1          1        1        1         1
#
#           India   Taiwan Philippines Singapore  Vietnam Malaysia Hong Kong  \
# count        26       23          25        26       13       27        27
# unique       26       23          25        26       13       27        27
# top      $1.99    $5.37       $3.99     $3.82    $0.16    $3.47     $2.84
# freq          1        1           1         1        1        1         1
#
#        New Zealand Australia      China Other_Asia_Pacific_Countries
# count           27        27         21                           27
# unique          26        27         20                           26
# ...

# %%
europe.describe()
# Out:
#        United Kingdom      Spain      Italy    Germany    Denmark    Hungary  \
# count       27.000000  27.000000  27.000000  27.000000  26.000000  25.000000
# mean        46.784815  12.378148  12.375556  20.506667   2.921923   1.554800
# std         29.380227   7.081643   7.251643  14.473195   2.194201   0.958984
# min         14.750000   4.150000   4.560000   2.460000   0.180000   0.310000
# 25%         26.000000   7.700000   8.045000   9.405000   1.207500   0.890000
# 50%         37.210000  10.310000   9.980000  19.040000   2.380000   1.380000
# 75%         55.425000  13.345000  13.230000  24.485000   3.797500   1.980000
# max        126.890000  32.670000  34.150000  63.290000  10.250000   4.500000
#
#          Finland  Netherlands    Iceland  Czech Republic  ...     Poland  \
# count  26.000000    27.000000  27.000000       27.000000  ...  26.000000
# mean    1.382692     5.022963   0.358519        1.834815  ...   3.053846
# ...

# %%
middle_east_and_africa.describe()
# Out:
#        United Arab Emirates     Israel  South Africa    Nigeria     Ghana  \
# count             27.000000  15.000000     27.000000  15.000000  7.000000
# mean               4.666667   1.595333      2.607037   0.266667  0.078571
# std                3.003495   0.881297      2.038170   0.347289  0.125357
# min                1.330000   0.490000      0.170000   0.030000  0.010000
# 25%                2.715000   0.735000      1.255000   0.065000  0.020000
# 50%                3.440000   1.340000      2.070000   0.140000  0.030000
# 75%                5.865000   2.300000      3.235000   0.275000  0.055000
# max               12.780000   3.150000      8.000000   1.360000  0.360000
#
#           Kenya  East Africa    Lebanon      Egypt   Kuwait     Turkey  \
# count  5.000000    10.000000  14.000000  15.000000  5.00000  25.000000
# mean   0.218000     0.156000   0.370000   0.666667  1.34600   3.036000
# std    0.081976     0.106792   0.213542   0.483701  0.68577   1.869075
# ...

# %%
north_america.describe()
# Out:
#        USA_and_Canada     Mexico  Central America  Caribbean
# count       27.000000  27.000000        27.000000  27.000000
# mean       367.573333  29.997037         7.386667   7.386667
# std        202.499840  19.861300         7.160980   7.160980
# min        134.810000   7.670000         0.700000   0.700000
# 25%        211.505000  15.625000         3.060000   3.060000
# 50%        319.030000  21.250000         5.750000   5.750000
# 75%        417.920000  37.365000         8.425000   8.425000
# max        858.370000  77.590000        36.720000  36.720000

# %%
south_america.describe()
# Out:
#        Venezuela   Colombia    Bolivia    Uruguay       Peru   Paraguay  \
# count  26.000000  27.000000  23.000000  22.000000  16.000000  10.000000
# mean    4.211538   5.228519   1.215217   0.337727   3.821250   0.519000
# std     4.799403   4.078081   0.892320   0.310559   2.097077   0.457103
# min     0.080000   0.750000   0.070000   0.020000   1.190000   0.170000
# 25%     1.035000   2.425000   0.640000   0.107500   2.285000   0.242500
# 50%     2.215000   3.490000   1.110000   0.215000   3.255000   0.360000
# 75%     6.072500   6.935000   1.470000   0.475000   5.250000   0.507500
# max    18.530000  17.690000   3.620000   1.370000   8.520000   1.560000
#
#            Chile    Ecuador  Argentina     Brazil  \
# count  26.000000  15.000000  27.000000  27.000000
# mean    4.560000   2.892667   6.140741  29.703704
# std     4.365348   2.119786   5.120792  20.545859
# min     0.320000   0.380000   0.940000   4.890000
# 25%     1.662500   1.315000   2.665000  13.255000
# ...

# %% [markdown]
# #### Are there any missing values?

# %%
asia_pacific.isna().any()
# Out:
# Movie Title                     True
# South Korea                     True
# Russia/CIS                      True
# Japan                           True
# Thailand                        True
# Indonesia                       True
# India                           True
# Taiwan                          True
# Philippines                     True
# Singapore                       True
# Vietnam                         True
# Malaysia                        True
# Hong Kong                       True
# New Zealand                     True
# Australia                       True
# China                           True
# Other_Asia_Pacific_Countries    True
# dtype: bool

# %%
europe.isna().any()
# Out:
# movie_title                 False
# United Kingdom              False
# Spain                       False
# Italy                       False
# Germany                     False
# Denmark                      True
# Hungary                      True
# Finland                      True
# Netherlands                 False
# Iceland                     False
# Czech Republic              False
# Switzerland                  True
# Slovakia                    False
# Ukraine                     False
# Portugal                    False
# Romania                      True
# Lithuania                    True
# Bulgaria                    False
# Latvia                       True
# Croatia                      True
# Austria                      True
# Poland                       True
# Serbia and Montenegro        True
# Estonia                      True
# Slovenia                    False
# Sweden                       True
# Belgium                      True
# ...

# %%
middle_east_and_africa.isna().any()
# Out:
# movie_title                                False
# United Arab Emirates                       False
# Israel                                      True
# South Africa                               False
# Nigeria                                     True
# Ghana                                       True
# Kenya                                       True
# East Africa                                 True
# Lebanon                                     True
# Egypt                                       True
# Kuwait                                      True
# Turkey                                      True
# Other_Middle_East_and_African_Countries    False
# dtype: bool

# %%
north_america.isna().any()
# Out:
# movie_title        False
# USA_and_Canada     False
# Mexico             False
# Central America    False
# Caribbean          False
# dtype: bool

# %%
south_america.isna().any()
# Out:
# movie_title                       False
# Venezuela                          True
# Colombia                          False
# Bolivia                            True
# Uruguay                            True
# Peru                               True
# Paraguay                           True
# Chile                              True
# Ecuador                            True
# Argentina                         False
# Brazil                            False
# Other_South_American_Countries    False
# dtype: bool

# %% [markdown]
# #### What are each columns datatypes?

# %%
asia_pacific.dtypes
# Out:
# Movie Title                     object
# South Korea                     object
# Russia/CIS                      object
# Japan                           object
# Thailand                        object
# Indonesia                       object
# India                           object
# Taiwan                          object
# Philippines                     object
# Singapore                       object
# Vietnam                         object
# Malaysia                        object
# Hong Kong                       object
# New Zealand                     object
# Australia                       object
# China                           object
# Other_Asia_Pacific_Countries    object
# dtype: object

# %%
europe.dtypes
# Out:
# movie_title                  object
# United Kingdom              float64
# Spain                       float64
# Italy                       float64
# Germany                     float64
# Denmark                     float64
# Hungary                     float64
# Finland                     float64
# Netherlands                 float64
# Iceland                     float64
# Czech Republic              float64
# Switzerland                 float64
# Slovakia                    float64
# Ukraine                     float64
# Portugal                    float64
# Romania                     float64
# Lithuania                   float64
# Bulgaria                    float64
# Latvia                      float64
# Croatia                     float64
# Austria                     float64
# Poland                      float64
# Serbia and Montenegro       float64
# Estonia                     float64
# Slovenia                    float64
# Sweden                      float64
# ...

# %%
middle_east_and_africa.dtypes
# Out:
# movie_title                                 object
# United Arab Emirates                       float64
# Israel                                     float64
# South Africa                               float64
# Nigeria                                    float64
# Ghana                                      float64
# Kenya                                      float64
# East Africa                                float64
# Lebanon                                    float64
# Egypt                                      float64
# Kuwait                                     float64
# Turkey                                     float64
# Other_Middle_East_and_African_Countries    float64
# dtype: object

# %%
north_america.dtypes
# Out:
# movie_title         object
# USA_and_Canada     float64
# Mexico             float64
# Central America    float64
# Caribbean          float64
# dtype: object

# %%
south_america.dtypes
# Out:
# movie_title                        object
# Venezuela                         float64
# Colombia                          float64
# Bolivia                           float64
# Uruguay                           float64
# Peru                              float64
# Paraguay                          float64
# Chile                             float64
# Ecuador                           float64
# Argentina                         float64
# Brazil                            float64
# Other_South_American_Countries    float64
# dtype: object

# %%
earnings_df = {"movie_title" : mcu_movie_info_df["movie_title"], "worldwide_collection" : mcu_movie_info_df["worldwide_collection_in_million_(USD)"]}

sorted_earnings_df = pd.DataFrame(data=earnings_df) 
sorted_earnings_df = sorted_earnings_df.sort_values(by="worldwide_collection", ascending=False)
plt.figure(figsize = (15,20))

graph_1 = sns.barplot(data=sorted_earnings_df, x="worldwide_collection", y="movie_title",orient="h")    
graph_1.set_xlabel("Worldwide Collection (Million USD)", fontsize = 20)
graph_1.set_ylabel("Movie Title", fontsize = 20)
graph_1.set_title("MCU worldwide box office collection", fontsize = 20)

graph_1.bar_label(graph_1.containers[0])
plt.show()
